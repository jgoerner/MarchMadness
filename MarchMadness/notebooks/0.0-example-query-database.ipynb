# %% [markdown]
# # About
# This notebooks shows how to connect to the database container

# %%
import pandas as pd
import sqlalchemy

# %%
# create postgres engine
engine = sqlalchemy.create_engine("postgres://postgres@postgres_container:5432")

# build query template
query = sqlalchemy.text("SELECT * FROM pg_catalog.pg_tables WHERE schemaname=:schema;")

# fire query
pd.read_sql(query, con=engine, params={"schema" : "public"})
# Out:
#    schemaname                               tablename tableowner tablespace  \
# 0      public                       t_original_Cities   postgres       None
# 1      public       t_original_ConferenceTourneyGames   postgres       None
# 2      public                  t_original_Conferences   postgres       None
# 3      public                   t_original_GameCities   postgres       None
# 4      public    t_original_NCAATourneyCompactResults   postgres       None
# 5      public   t_original_NCAATourneyDetailedResults   postgres       None
# 6      public    t_original_NCAATourneySeedRoundSlots   postgres       None
# 7      public             t_original_NCAATourneySeeds   postgres       None
# 8      public             t_original_NCAATourneySlots   postgres       None
# 9      public                 t_original_Players_2010   postgres       None
# 10     public                 t_original_Players_2011   postgres       None
# 11     public                 t_original_Players_2012   postgres       None
# 12     public                 t_original_Players_2013   postgres       None
# 13     public                 t_original_Players_2014   postgres       None
# 14     public                 t_original_Players_2015   postgres       None
# 15     public                 t_original_Players_2016   postgres       None
# 16     public                 t_original_Players_2017   postgres       None
# 17     public  t_original_RegularSeasonCompactResults   postgres       None
#
#    hasindexes hasrules hastriggers rowsecurity
# 0        True    False       False       False
# 1        True    False       False       False
# 2        True    False       False       False
# 3        True    False       False       False
# 4        True    False       False       False
# 5        True    False       False       False
# 6        True    False       False       False
# 7        True    False       False       False
# 8        True    False       False       False
# 9        True    False       False       False
# 10       True    False       False       False
# 11       True    False       False       False
# 12       True    False       False       False
# 13       True    False       False       False
# 14       True    False       False       False
# 15       True    False       False       False
# 16       True    False       False       False
# 17       True    False       False       False
